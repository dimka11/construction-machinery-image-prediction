# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from PIL import Image
from IPython.display import display
from pathlib import Path
import wandb
from kaggle_secrets import UserSecretsClient

import seaborn as sn
import matplotlib.pyplot as plt

# %%
wandb.login(key=UserSecretsClient().get_secret("wan_db"))
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# Metric:
#
# Recall

# %%
train_dir = '../input/construction-machinery-cls/train_dataset_train/train'
test_dir = '../input/construction-machinery-cls/test_dataset_test/test'
test = pd.read_csv('../input/construction-machinery-cls/test_dataset_test/test.csv')
train = pd.read_csv('../input/construction-machinery-cls/train_dataset_train/train.csv')
train['class'] = train['class'].astype(int)

# %%
test.head(5)
# Out:
#   ID_img  class
# 0  0.jpg      0
# 1  1.jpg      0
# 2  2.jpg      0
# 3  3.jpg      0
# 4  4.jpg      0

# %%
train.head(5)
# Out:
#      ID_img  class
# 0  2138.jpg      4
# 1  2139.jpg      6
# 2  2140.jpg      3
# 3  2141.jpg      6
# 4  2142.jpg      3

# %%
train['class'].value_counts()
# Out:
# 1    1586
# 3     969
# 4     797
# 5     514
# 0     321
# 2     316
# 6     293
# 7     194
# Name: class, dtype: int64

# %%
len(train['class'].unique())
# Out:
# 8

# %%
# X_train, X_test, y_train, y_test = train_test_split(train['ID_img'], train['class'], test_size=0.2, random_state=42, stratify=train['class'])

# %%
train['path'] = train['ID_img'].apply(lambda x: f'{train_dir}/{x}')
test['path'] = test['ID_img'].apply(lambda x: f'{test_dir}/{x}')

# %%
Image.open(train['path'].iloc[5]).size
# Out:
# (128, 112)

# %%
import datasets

features = datasets.Features({
    'image': datasets.Image(),
    'label': datasets.Value('int32')
})

dataset_dict = {
    'image': train['path'].values,
    'label': train['class'].values
}

dataset = datasets.Dataset.from_dict(dataset_dict, features)

# %%
display(dataset[0]['image'], dataset[2]['image'], dataset[3]['image'], dataset[4]['image'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x99>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x95>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %%
features = datasets.Features({
    'image': datasets.Image(),
    'label': datasets.Value('int32')
})

dataset_dict = {
    'image': test['path'].values,
    'label': test['class'].values
}

test_dataset = datasets.Dataset.from_dict(dataset_dict, features)
test = test.drop(columns=['path'])

# %%
dataset = dataset.train_test_split(test_size=0.1,)
dataset["train"][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>,
#  'label': 3}

# %% [markdown]
# Preprocess

# %%
from transformers import AutoFeatureExtractor

feature_extractor_swin = AutoFeatureExtractor.from_pretrained("microsoft/swin-tiny-patch4-window7-224")
feature_extractor_convn = AutoFeatureExtractor.from_pretrained("facebook/convnext-tiny-224")
# Out:
# Downloading:   0%|          | 0.00/255 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/266 [00:00<?, ?B/s]

# %%
feature_extractor_swin
# Out:
# ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 3,
#   "size": 224
# }

# %%
from torchvision.transforms import RandomResizedCrop, Compose, Normalize, ToTensor # REPLACE to resize

normalize = Normalize(mean=feature_extractor_swin.image_mean, std=feature_extractor_swin.image_std)
_transforms = Compose([RandomResizedCrop(feature_extractor_swin.size), ToTensor(), normalize])

def transforms(examples):
    examples["pixel_values"] = [_transforms(img.convert("RGB")) for img in examples["image"]]
    del examples["image"]
    return examples

# %%
dataset = dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

from transformers import DefaultDataCollator

data_collator = DefaultDataCollator()

# %% [markdown]
# Train

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model_swin = AutoModelForImageClassification.from_pretrained(
    "microsoft/swin-tiny-patch4-window7-224",
    num_labels=len(train['class'].value_counts()),
    ignore_mismatched_sizes=True)
# Out:
# Downloading:   0%|          | 0.00/70.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/108M [00:00<?, ?B/s]
# /opt/conda/lib/python3.7/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:2227.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Some weights of SwinForImageClassification were not initialized from the model checkpoint at microsoft/swin-tiny-patch4-window7-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([8, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([8]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./results_swin",
    per_device_train_batch_size=32, # 16
    evaluation_strategy="steps",
    num_train_epochs=90, # 40
    fp16=True,
    save_steps=100,
    eval_steps=100,
    logging_steps=10,
    learning_rate=2e-4,
    save_total_limit=2,
    remove_unused_columns=False,
)

trainer = Trainer(
    model=model_swin,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=feature_extractor_swin,
)

trainer.train()
# Out:
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 4491
#   Num Epochs = 90
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 6390
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: dimka11. Use `wandb login --relogin` to force relogin
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20221105_161146-ego1fa5f</code>
# Syncing run <strong><a href="https://wandb.ai/dimka11/huggingface/runs/ego1fa5f" target="_blank">./results_swin</a></strong> to <a href="https://wandb.ai/dimka11/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='6390' max='6390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6390/6390 58:27, Epoch 90/90]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.389600</td>
#       <td>0.243241</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.213900</td>
#       <td>0.237356</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.195600</td>
#       <td>0.277396</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.184200</td>
#       <td>0.228466</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.205800</td>
#       <td>0.251544</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.173000</td>
#       <td>0.230664</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.156600</td>
#       <td>0.194165</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.173100</td>
#       <td>0.295823</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.150200</td>
#       <td>0.269284</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.112400</td>
#       <td>0.209980</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.143000</td>
#       <td>0.241063</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.121600</td>
#       <td>0.245598</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.120100</td>
#       <td>0.144401</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.130100</td>
#       <td>0.185045</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.099500</td>
#       <td>0.234341</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.116900</td>
#       <td>0.195783</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.102100</td>
#       <td>0.160174</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.116000</td>
#       <td>0.211019</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.126600</td>
#       <td>0.113414</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.095200</td>
#       <td>0.129648</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.057500</td>
#       <td>0.154309</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.089400</td>
#       <td>0.214466</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.074800</td>
#       <td>0.181894</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.075000</td>
#       <td>0.170487</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.102500</td>
#       <td>0.204561</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.058200</td>
#       <td>0.110446</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.091300</td>
#       <td>0.156385</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.120800</td>
#       <td>0.096114</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.086800</td>
#       <td>0.128525</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.072300</td>
#       <td>0.132635</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.081200</td>
#       <td>0.168918</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.091100</td>
#       <td>0.186377</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.074100</td>
#       <td>0.210247</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.038400</td>
#       <td>0.196956</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.063900</td>
#       <td>0.124142</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.031800</td>
#       <td>0.158798</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.026800</td>
#       <td>0.166974</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.084900</td>
#       <td>0.155892</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.046400</td>
#       <td>0.185398</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.086300</td>
#       <td>0.154737</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.041300</td>
#       <td>0.129932</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.054400</td>
#       <td>0.193086</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.027800</td>
#       <td>0.116914</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.030800</td>
#       <td>0.158232</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.069200</td>
#       <td>0.123667</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.030400</td>
#       <td>0.117953</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.048500</td>
#       <td>0.118013</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.051000</td>
#       <td>0.101840</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.012800</td>
#       <td>0.113349</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.045800</td>
#       <td>0.123652</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.029900</td>
#       <td>0.112411</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.036800</td>
#       <td>0.118625</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.018300</td>
#       <td>0.116838</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.019600</td>
#       <td>0.154013</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.055000</td>
#       <td>0.101778</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.028700</td>
#       <td>0.078614</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.046000</td>
#       <td>0.152367</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.024600</td>
#       <td>0.075686</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.022100</td>
#       <td>0.080914</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.014500</td>
#       <td>0.077745</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.028800</td>
#       <td>0.114434</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.046900</td>
#       <td>0.134744</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.019100</td>
#       <td>0.091238</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-100
# Configuration saved in ./results_swin/checkpoint-100/config.json
# Model weights saved in ./results_swin/checkpoint-100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-100/preprocessor_config.json
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-200
# Configuration saved in ./results_swin/checkpoint-200/config.json
# Model weights saved in ./results_swin/checkpoint-200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-200/preprocessor_config.json
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-300
# Configuration saved in ./results_swin/checkpoint-300/config.json
# Model weights saved in ./results_swin/checkpoint-300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-400
# Configuration saved in ./results_swin/checkpoint-400/config.json
# Model weights saved in ./results_swin/checkpoint-400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-500
# Configuration saved in ./results_swin/checkpoint-500/config.json
# Model weights saved in ./results_swin/checkpoint-500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-600
# Configuration saved in ./results_swin/checkpoint-600/config.json
# Model weights saved in ./results_swin/checkpoint-600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-700
# Configuration saved in ./results_swin/checkpoint-700/config.json
# Model weights saved in ./results_swin/checkpoint-700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-800
# Configuration saved in ./results_swin/checkpoint-800/config.json
# Model weights saved in ./results_swin/checkpoint-800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-900
# Configuration saved in ./results_swin/checkpoint-900/config.json
# Model weights saved in ./results_swin/checkpoint-900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1000
# Configuration saved in ./results_swin/checkpoint-1000/config.json
# Model weights saved in ./results_swin/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1100
# Configuration saved in ./results_swin/checkpoint-1100/config.json
# Model weights saved in ./results_swin/checkpoint-1100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1200
# Configuration saved in ./results_swin/checkpoint-1200/config.json
# Model weights saved in ./results_swin/checkpoint-1200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1300
# Configuration saved in ./results_swin/checkpoint-1300/config.json
# Model weights saved in ./results_swin/checkpoint-1300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1400
# Configuration saved in ./results_swin/checkpoint-1400/config.json
# Model weights saved in ./results_swin/checkpoint-1400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1500
# Configuration saved in ./results_swin/checkpoint-1500/config.json
# Model weights saved in ./results_swin/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1600
# Configuration saved in ./results_swin/checkpoint-1600/config.json
# Model weights saved in ./results_swin/checkpoint-1600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1700
# Configuration saved in ./results_swin/checkpoint-1700/config.json
# Model weights saved in ./results_swin/checkpoint-1700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1800
# Configuration saved in ./results_swin/checkpoint-1800/config.json
# Model weights saved in ./results_swin/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-1900
# Configuration saved in ./results_swin/checkpoint-1900/config.json
# Model weights saved in ./results_swin/checkpoint-1900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-1900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2000
# Configuration saved in ./results_swin/checkpoint-2000/config.json
# Model weights saved in ./results_swin/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2100
# Configuration saved in ./results_swin/checkpoint-2100/config.json
# Model weights saved in ./results_swin/checkpoint-2100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-1900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2200
# Configuration saved in ./results_swin/checkpoint-2200/config.json
# Model weights saved in ./results_swin/checkpoint-2200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2300
# Configuration saved in ./results_swin/checkpoint-2300/config.json
# Model weights saved in ./results_swin/checkpoint-2300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2400
# Configuration saved in ./results_swin/checkpoint-2400/config.json
# Model weights saved in ./results_swin/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2500
# Configuration saved in ./results_swin/checkpoint-2500/config.json
# Model weights saved in ./results_swin/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2600
# Configuration saved in ./results_swin/checkpoint-2600/config.json
# Model weights saved in ./results_swin/checkpoint-2600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2700
# Configuration saved in ./results_swin/checkpoint-2700/config.json
# Model weights saved in ./results_swin/checkpoint-2700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2800
# Configuration saved in ./results_swin/checkpoint-2800/config.json
# Model weights saved in ./results_swin/checkpoint-2800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-2900
# Configuration saved in ./results_swin/checkpoint-2900/config.json
# Model weights saved in ./results_swin/checkpoint-2900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-2900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3000
# Configuration saved in ./results_swin/checkpoint-3000/config.json
# Model weights saved in ./results_swin/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3100
# Configuration saved in ./results_swin/checkpoint-3100/config.json
# Model weights saved in ./results_swin/checkpoint-3100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-2900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3200
# Configuration saved in ./results_swin/checkpoint-3200/config.json
# Model weights saved in ./results_swin/checkpoint-3200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3300
# Configuration saved in ./results_swin/checkpoint-3300/config.json
# Model weights saved in ./results_swin/checkpoint-3300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3400
# Configuration saved in ./results_swin/checkpoint-3400/config.json
# Model weights saved in ./results_swin/checkpoint-3400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3500
# Configuration saved in ./results_swin/checkpoint-3500/config.json
# Model weights saved in ./results_swin/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3600
# Configuration saved in ./results_swin/checkpoint-3600/config.json
# Model weights saved in ./results_swin/checkpoint-3600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3700
# Configuration saved in ./results_swin/checkpoint-3700/config.json
# Model weights saved in ./results_swin/checkpoint-3700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3800
# Configuration saved in ./results_swin/checkpoint-3800/config.json
# Model weights saved in ./results_swin/checkpoint-3800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-3900
# Configuration saved in ./results_swin/checkpoint-3900/config.json
# Model weights saved in ./results_swin/checkpoint-3900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-3900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4000
# Configuration saved in ./results_swin/checkpoint-4000/config.json
# Model weights saved in ./results_swin/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4100
# Configuration saved in ./results_swin/checkpoint-4100/config.json
# Model weights saved in ./results_swin/checkpoint-4100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-3900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4200
# Configuration saved in ./results_swin/checkpoint-4200/config.json
# Model weights saved in ./results_swin/checkpoint-4200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4300
# Configuration saved in ./results_swin/checkpoint-4300/config.json
# Model weights saved in ./results_swin/checkpoint-4300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4400
# Configuration saved in ./results_swin/checkpoint-4400/config.json
# Model weights saved in ./results_swin/checkpoint-4400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4500
# Configuration saved in ./results_swin/checkpoint-4500/config.json
# Model weights saved in ./results_swin/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4600
# Configuration saved in ./results_swin/checkpoint-4600/config.json
# Model weights saved in ./results_swin/checkpoint-4600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4700
# Configuration saved in ./results_swin/checkpoint-4700/config.json
# Model weights saved in ./results_swin/checkpoint-4700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4800
# Configuration saved in ./results_swin/checkpoint-4800/config.json
# Model weights saved in ./results_swin/checkpoint-4800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-4900
# Configuration saved in ./results_swin/checkpoint-4900/config.json
# Model weights saved in ./results_swin/checkpoint-4900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-4900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5000
# Configuration saved in ./results_swin/checkpoint-5000/config.json
# Model weights saved in ./results_swin/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5100
# Configuration saved in ./results_swin/checkpoint-5100/config.json
# Model weights saved in ./results_swin/checkpoint-5100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-4900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5200
# Configuration saved in ./results_swin/checkpoint-5200/config.json
# Model weights saved in ./results_swin/checkpoint-5200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5300
# Configuration saved in ./results_swin/checkpoint-5300/config.json
# Model weights saved in ./results_swin/checkpoint-5300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5400
# Configuration saved in ./results_swin/checkpoint-5400/config.json
# Model weights saved in ./results_swin/checkpoint-5400/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5400/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5500
# Configuration saved in ./results_swin/checkpoint-5500/config.json
# Model weights saved in ./results_swin/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5600
# Configuration saved in ./results_swin/checkpoint-5600/config.json
# Model weights saved in ./results_swin/checkpoint-5600/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5600/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5700
# Configuration saved in ./results_swin/checkpoint-5700/config.json
# Model weights saved in ./results_swin/checkpoint-5700/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5700/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5800
# Configuration saved in ./results_swin/checkpoint-5800/config.json
# Model weights saved in ./results_swin/checkpoint-5800/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5800/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-5900
# Configuration saved in ./results_swin/checkpoint-5900/config.json
# Model weights saved in ./results_swin/checkpoint-5900/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-5900/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-6000
# Configuration saved in ./results_swin/checkpoint-6000/config.json
# Model weights saved in ./results_swin/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-6000/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-6100
# Configuration saved in ./results_swin/checkpoint-6100/config.json
# Model weights saved in ./results_swin/checkpoint-6100/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-6100/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-5900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-6200
# Configuration saved in ./results_swin/checkpoint-6200/config.json
# Model weights saved in ./results_swin/checkpoint-6200/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-6200/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-6000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_swin/checkpoint-6300
# Configuration saved in ./results_swin/checkpoint-6300/config.json
# Model weights saved in ./results_swin/checkpoint-6300/pytorch_model.bin
# Feature extractor saved in ./results_swin/checkpoint-6300/preprocessor_config.json
# Deleting older checkpoint [results_swin/checkpoint-6100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6390, training_loss=0.089123445368009, metrics={'train_runtime': 3530.9536, 'train_samples_per_second': 114.47, 'train_steps_per_second': 1.81, 'total_flos': 1.0048226535693804e+19, 'train_loss': 0.089123445368009, 'epoch': 90.0})

# %%
Path("./weights").mkdir(parents=True, exist_ok=True)

# %%
model_swin.save_pretrained('./weights/swin-tiny-patch4-window7-224_fine_tuned')
feature_extractor_swin.save_pretrained('./weights/swin-tiny-patch4-window7-224_feature_extractor')
# Out:
# Configuration saved in ./weights/swin-tiny-patch4-window7-224_fine_tuned/config.json
# Model weights saved in ./weights/swin-tiny-patch4-window7-224_fine_tuned/pytorch_model.bin
# Feature extractor saved in ./weights/swin-tiny-patch4-window7-224_feature_extractor/preprocessor_config.json
# ['./weights/swin-tiny-patch4-window7-224_feature_extractor/preprocessor_config.json']

# %%
# load
# from transformers import BeitFeatureExtractor, BeitModel, BeitConfig
# import torch

# feature_extractor = BeitFeatureExtractor.from_pretrained("./weights/beit-base-patch16-224_feature_extractor")
# model = BeitModel.from_pretrained("./weights/beit-base-patch16-224_fine_tuned")

# %% [markdown]
# eval

# %%
preds = trainer.predict(dataset['test'])
preds.predictions.shape, preds.label_ids.shape
# Out:
# ***** Running Prediction *****
#   Num examples = 499
#   Batch size = 16
#     <div>
#
#       <progress value='166' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:30]
#     </div>
# ((499, 8), (499,))

# %%
accuracy_score(preds.label_ids, np.argmax(preds.predictions, axis=1))
# Out:
# 0.9679358717434869

# %%
f1_score(preds.label_ids, np.argmax(preds.predictions, axis=1), average='macro')
# Out:
# 0.958867545184179

# %%
cm = confusion_matrix(preds.label_ids, np.argmax(preds.predictions, axis=1))

df_cm = pd.DataFrame(cm, index = [i for i in "01234567"],
                  columns = [i for i in "01234567"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
recall_score(preds.label_ids, np.argmax(preds.predictions, axis=1), average='macro')
# Out:
# 0.958852083099673

# %% [markdown]
# Predict test

# %%
preds_test = trainer.predict(test_dataset)
np.save('./swin_preds.npy', preds_test)
test['class'] = np.argmax(preds_test.predictions, axis=1)
test.to_csv('swin_90epoch.csv', index=False)
# Out:
# ***** Running Prediction *****
#   Num examples = 2138
#   Batch size = 16
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# ConvNext

# %%
model_conv = AutoModelForImageClassification.from_pretrained(
    "facebook/convnext-tiny-224",
    num_labels=len(train['class'].value_counts()),
    ignore_mismatched_sizes=True)
# Out:
# https://huggingface.co/facebook/convnext-tiny-224/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpc27mq1f1
# Downloading:   0%|          | 0.00/68.0k [00:00<?, ?B/s]
# storing https://huggingface.co/facebook/convnext-tiny-224/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/741b590dfc3966dd77875cd496d6f9097645132a8e8106ab873b7d130da4cab9.fba866a30db31ba0d3bb63ddbdaccc3ba609c530ee38ca0150a68f3c9a8d6ccf
# creating metadata file for /root/.cache/huggingface/transformers/741b590dfc3966dd77875cd496d6f9097645132a8e8106ab873b7d130da4cab9.fba866a30db31ba0d3bb63ddbdaccc3ba609c530ee38ca0150a68f3c9a8d6ccf
# loading configuration file https://huggingface.co/facebook/convnext-tiny-224/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/741b590dfc3966dd77875cd496d6f9097645132a8e8106ab873b7d130da4cab9.fba866a30db31ba0d3bb63ddbdaccc3ba609c530ee38ca0150a68f3c9a8d6ccf
# Model config ConvNextConfig {
#   "_name_or_path": "facebook/convnext-tiny-224",
#   "architectures": [
#     "ConvNextForImageClassification"
#   ],
#   "depths": [
#     3,
#     3,
#     9,
#     3
#   ],
#   "drop_path_rate": 0.0,
#   "hidden_act": "gelu",
#   "hidden_sizes": [
#     96,
#     192,
#     384,
#     768
#   ],
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7"
#   },
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7
#   },
#   "layer_norm_eps": 1e-12,
#   "layer_scale_init_value": 1e-06,
#   "model_type": "convnext",
#   "num_channels": 3,
#   "num_stages": 4,
#   "patch_size": 4,
#   "torch_dtype": "float32",
#   "transformers_version": "4.20.1"
# }
#
# https://huggingface.co/facebook/convnext-tiny-224/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpywn8yz4l
# Downloading:   0%|          | 0.00/109M [00:00<?, ?B/s]
# storing https://huggingface.co/facebook/convnext-tiny-224/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/f6cde2591c44e990d97372da4184ff364f9270bd3e051a10e9ebc7f077b2c276.6164ec88009a0d416d211404f7a5feaafb35327b50613e99aec53791a3daabdc
# creating metadata file for /root/.cache/huggingface/transformers/f6cde2591c44e990d97372da4184ff364f9270bd3e051a10e9ebc7f077b2c276.6164ec88009a0d416d211404f7a5feaafb35327b50613e99aec53791a3daabdc
# loading weights file https://huggingface.co/facebook/convnext-tiny-224/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/f6cde2591c44e990d97372da4184ff364f9270bd3e051a10e9ebc7f077b2c276.6164ec88009a0d416d211404f7a5feaafb35327b50613e99aec53791a3daabdc
# All model checkpoint weights were used when initializing ConvNextForImageClassification.
#
# Some weights of ConvNextForImageClassification were not initialized from the model checkpoint at facebook/convnext-tiny-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([8, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([8]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./results_convnext",
    per_device_train_batch_size=32, # 16
    evaluation_strategy="steps",
    num_train_epochs=90, # 40
    fp16=True,
    save_steps=100,
    eval_steps=100,
    logging_steps=10,
    learning_rate=2e-4,
    save_total_limit=2,
    remove_unused_columns=False,
)

trainer = Trainer(
    model=model_conv,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=feature_extractor_convn,
)

trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 4491
#   Num Epochs = 90
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 6390
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='6390' max='6390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6390/6390 57:11, Epoch 90/90]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.258700</td>
#       <td>0.313910</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.153900</td>
#       <td>0.220089</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.121300</td>
#       <td>0.217397</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.117700</td>
#       <td>0.201094</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.126700</td>
#       <td>0.152249</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.050100</td>
#       <td>0.188279</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.092900</td>
#       <td>0.206712</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.086900</td>
#       <td>0.168791</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.097300</td>
#       <td>0.224353</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.074400</td>
#       <td>0.131976</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.054600</td>
#       <td>0.118804</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.080300</td>
#       <td>0.138481</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.075700</td>
#       <td>0.119697</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.062700</td>
#       <td>0.150034</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.031100</td>
#       <td>0.121133</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.050400</td>
#       <td>0.195579</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.045600</td>
#       <td>0.130954</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.056600</td>
#       <td>0.165501</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.075900</td>
#       <td>0.132420</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.087000</td>
#       <td>0.115976</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.025000</td>
#       <td>0.114234</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.035900</td>
#       <td>0.148380</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.043300</td>
#       <td>0.131132</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.073200</td>
#       <td>0.107616</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.045300</td>
#       <td>0.167299</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.044200</td>
#       <td>0.097949</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.022600</td>
#       <td>0.146593</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.078400</td>
#       <td>0.091031</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.041400</td>
#       <td>0.100641</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.037200</td>
#       <td>0.105704</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.022800</td>
#       <td>0.109702</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.037900</td>
#       <td>0.162693</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.051200</td>
#       <td>0.135259</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.023600</td>
#       <td>0.162973</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.023400</td>
#       <td>0.101553</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.004900</td>
#       <td>0.156966</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.018400</td>
#       <td>0.195697</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.034200</td>
#       <td>0.139277</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.033800</td>
#       <td>0.138006</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.028400</td>
#       <td>0.127913</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.032400</td>
#       <td>0.108741</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.019100</td>
#       <td>0.177517</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.013600</td>
#       <td>0.098370</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.027700</td>
#       <td>0.115729</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.023400</td>
#       <td>0.126812</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.031700</td>
#       <td>0.094051</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.025800</td>
#       <td>0.092107</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.020400</td>
#       <td>0.088529</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.009600</td>
#       <td>0.123641</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.024100</td>
#       <td>0.125644</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.023900</td>
#       <td>0.097937</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.029900</td>
#       <td>0.112458</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.014600</td>
#       <td>0.127377</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.004400</td>
#       <td>0.140368</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.014600</td>
#       <td>0.083813</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.019800</td>
#       <td>0.109958</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.021000</td>
#       <td>0.119365</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.017000</td>
#       <td>0.099464</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.018500</td>
#       <td>0.072856</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.007100</td>
#       <td>0.097995</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.019500</td>
#       <td>0.127355</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.031500</td>
#       <td>0.100548</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.005700</td>
#       <td>0.107276</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-100
# Configuration saved in ./results_convnext/checkpoint-100/config.json
# Model weights saved in ./results_convnext/checkpoint-100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-100/preprocessor_config.json
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-200
# Configuration saved in ./results_convnext/checkpoint-200/config.json
# Model weights saved in ./results_convnext/checkpoint-200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-200/preprocessor_config.json
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-300
# Configuration saved in ./results_convnext/checkpoint-300/config.json
# Model weights saved in ./results_convnext/checkpoint-300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-400
# Configuration saved in ./results_convnext/checkpoint-400/config.json
# Model weights saved in ./results_convnext/checkpoint-400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-500
# Configuration saved in ./results_convnext/checkpoint-500/config.json
# Model weights saved in ./results_convnext/checkpoint-500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-600
# Configuration saved in ./results_convnext/checkpoint-600/config.json
# Model weights saved in ./results_convnext/checkpoint-600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-700
# Configuration saved in ./results_convnext/checkpoint-700/config.json
# Model weights saved in ./results_convnext/checkpoint-700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-800
# Configuration saved in ./results_convnext/checkpoint-800/config.json
# Model weights saved in ./results_convnext/checkpoint-800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-900
# Configuration saved in ./results_convnext/checkpoint-900/config.json
# Model weights saved in ./results_convnext/checkpoint-900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1000
# Configuration saved in ./results_convnext/checkpoint-1000/config.json
# Model weights saved in ./results_convnext/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1100
# Configuration saved in ./results_convnext/checkpoint-1100/config.json
# Model weights saved in ./results_convnext/checkpoint-1100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1200
# Configuration saved in ./results_convnext/checkpoint-1200/config.json
# Model weights saved in ./results_convnext/checkpoint-1200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1300
# Configuration saved in ./results_convnext/checkpoint-1300/config.json
# Model weights saved in ./results_convnext/checkpoint-1300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1400
# Configuration saved in ./results_convnext/checkpoint-1400/config.json
# Model weights saved in ./results_convnext/checkpoint-1400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1500
# Configuration saved in ./results_convnext/checkpoint-1500/config.json
# Model weights saved in ./results_convnext/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1600
# Configuration saved in ./results_convnext/checkpoint-1600/config.json
# Model weights saved in ./results_convnext/checkpoint-1600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1700
# Configuration saved in ./results_convnext/checkpoint-1700/config.json
# Model weights saved in ./results_convnext/checkpoint-1700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1800
# Configuration saved in ./results_convnext/checkpoint-1800/config.json
# Model weights saved in ./results_convnext/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-1900
# Configuration saved in ./results_convnext/checkpoint-1900/config.json
# Model weights saved in ./results_convnext/checkpoint-1900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-1900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2000
# Configuration saved in ./results_convnext/checkpoint-2000/config.json
# Model weights saved in ./results_convnext/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2100
# Configuration saved in ./results_convnext/checkpoint-2100/config.json
# Model weights saved in ./results_convnext/checkpoint-2100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-1900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2200
# Configuration saved in ./results_convnext/checkpoint-2200/config.json
# Model weights saved in ./results_convnext/checkpoint-2200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2300
# Configuration saved in ./results_convnext/checkpoint-2300/config.json
# Model weights saved in ./results_convnext/checkpoint-2300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2400
# Configuration saved in ./results_convnext/checkpoint-2400/config.json
# Model weights saved in ./results_convnext/checkpoint-2400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2500
# Configuration saved in ./results_convnext/checkpoint-2500/config.json
# Model weights saved in ./results_convnext/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2600
# Configuration saved in ./results_convnext/checkpoint-2600/config.json
# Model weights saved in ./results_convnext/checkpoint-2600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2700
# Configuration saved in ./results_convnext/checkpoint-2700/config.json
# Model weights saved in ./results_convnext/checkpoint-2700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2800
# Configuration saved in ./results_convnext/checkpoint-2800/config.json
# Model weights saved in ./results_convnext/checkpoint-2800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-2900
# Configuration saved in ./results_convnext/checkpoint-2900/config.json
# Model weights saved in ./results_convnext/checkpoint-2900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-2900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3000
# Configuration saved in ./results_convnext/checkpoint-3000/config.json
# Model weights saved in ./results_convnext/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3100
# Configuration saved in ./results_convnext/checkpoint-3100/config.json
# Model weights saved in ./results_convnext/checkpoint-3100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-2900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3200
# Configuration saved in ./results_convnext/checkpoint-3200/config.json
# Model weights saved in ./results_convnext/checkpoint-3200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3300
# Configuration saved in ./results_convnext/checkpoint-3300/config.json
# Model weights saved in ./results_convnext/checkpoint-3300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3400
# Configuration saved in ./results_convnext/checkpoint-3400/config.json
# Model weights saved in ./results_convnext/checkpoint-3400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3500
# Configuration saved in ./results_convnext/checkpoint-3500/config.json
# Model weights saved in ./results_convnext/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3600
# Configuration saved in ./results_convnext/checkpoint-3600/config.json
# Model weights saved in ./results_convnext/checkpoint-3600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3700
# Configuration saved in ./results_convnext/checkpoint-3700/config.json
# Model weights saved in ./results_convnext/checkpoint-3700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3800
# Configuration saved in ./results_convnext/checkpoint-3800/config.json
# Model weights saved in ./results_convnext/checkpoint-3800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-3900
# Configuration saved in ./results_convnext/checkpoint-3900/config.json
# Model weights saved in ./results_convnext/checkpoint-3900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-3900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4000
# Configuration saved in ./results_convnext/checkpoint-4000/config.json
# Model weights saved in ./results_convnext/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4100
# Configuration saved in ./results_convnext/checkpoint-4100/config.json
# Model weights saved in ./results_convnext/checkpoint-4100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-3900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4200
# Configuration saved in ./results_convnext/checkpoint-4200/config.json
# Model weights saved in ./results_convnext/checkpoint-4200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4300
# Configuration saved in ./results_convnext/checkpoint-4300/config.json
# Model weights saved in ./results_convnext/checkpoint-4300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4400
# Configuration saved in ./results_convnext/checkpoint-4400/config.json
# Model weights saved in ./results_convnext/checkpoint-4400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4500
# Configuration saved in ./results_convnext/checkpoint-4500/config.json
# Model weights saved in ./results_convnext/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4600
# Configuration saved in ./results_convnext/checkpoint-4600/config.json
# Model weights saved in ./results_convnext/checkpoint-4600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4700
# Configuration saved in ./results_convnext/checkpoint-4700/config.json
# Model weights saved in ./results_convnext/checkpoint-4700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4800
# Configuration saved in ./results_convnext/checkpoint-4800/config.json
# Model weights saved in ./results_convnext/checkpoint-4800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-4900
# Configuration saved in ./results_convnext/checkpoint-4900/config.json
# Model weights saved in ./results_convnext/checkpoint-4900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-4900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5000
# Configuration saved in ./results_convnext/checkpoint-5000/config.json
# Model weights saved in ./results_convnext/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5100
# Configuration saved in ./results_convnext/checkpoint-5100/config.json
# Model weights saved in ./results_convnext/checkpoint-5100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-4900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5200
# Configuration saved in ./results_convnext/checkpoint-5200/config.json
# Model weights saved in ./results_convnext/checkpoint-5200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5300
# Configuration saved in ./results_convnext/checkpoint-5300/config.json
# Model weights saved in ./results_convnext/checkpoint-5300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5400
# Configuration saved in ./results_convnext/checkpoint-5400/config.json
# Model weights saved in ./results_convnext/checkpoint-5400/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5400/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5200] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5500
# Configuration saved in ./results_convnext/checkpoint-5500/config.json
# Model weights saved in ./results_convnext/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5300] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5600
# Configuration saved in ./results_convnext/checkpoint-5600/config.json
# Model weights saved in ./results_convnext/checkpoint-5600/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5600/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5400] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5700
# Configuration saved in ./results_convnext/checkpoint-5700/config.json
# Model weights saved in ./results_convnext/checkpoint-5700/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5700/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5500] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5800
# Configuration saved in ./results_convnext/checkpoint-5800/config.json
# Model weights saved in ./results_convnext/checkpoint-5800/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5800/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5600] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-5900
# Configuration saved in ./results_convnext/checkpoint-5900/config.json
# Model weights saved in ./results_convnext/checkpoint-5900/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-5900/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5700] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-6000
# Configuration saved in ./results_convnext/checkpoint-6000/config.json
# Model weights saved in ./results_convnext/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-6000/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5800] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-6100
# Configuration saved in ./results_convnext/checkpoint-6100/config.json
# Model weights saved in ./results_convnext/checkpoint-6100/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-6100/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-5900] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-6200
# Configuration saved in ./results_convnext/checkpoint-6200/config.json
# Model weights saved in ./results_convnext/checkpoint-6200/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-6200/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-6000] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 499
#   Batch size = 16
# Saving model checkpoint to ./results_convnext/checkpoint-6300
# Configuration saved in ./results_convnext/checkpoint-6300/config.json
# Model weights saved in ./results_convnext/checkpoint-6300/pytorch_model.bin
# Feature extractor saved in ./results_convnext/checkpoint-6300/preprocessor_config.json
# Deleting older checkpoint [results_convnext/checkpoint-6100] due to args.save_total_limit
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6390, training_loss=0.05424962586406997, metrics={'train_runtime': 3432.0988, 'train_samples_per_second': 117.768, 'train_steps_per_second': 1.862, 'total_flos': 1.0158024527710618e+19, 'train_loss': 0.05424962586406997, 'epoch': 90.0})

# %%
preds = trainer.predict(dataset['test'])
preds.predictions.shape, preds.label_ids.shape
# Out:
# ***** Running Prediction *****
#   Num examples = 499
#   Batch size = 16
#     <div>
#
#       <progress value='166' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:18]
#     </div>
# ((499, 8), (499,))

# %%
recall_score(preds.label_ids, np.argmax(preds.predictions, axis=1), average='macro')
# Out:
# 0.9552773512763054

# %%
model_conv.save_pretrained('./weights/convnext-tiny-224_fine_tuned')
feature_extractor_convn.save_pretrained('./weights/convnext-tiny-224_feature_extractor')
# Out:
# Configuration saved in ./weights/convnext-tiny-224_fine_tuned/config.json
# Model weights saved in ./weights/convnext-tiny-224_fine_tuned/pytorch_model.bin
# Feature extractor saved in ./weights/convnext-tiny-224_feature_extractor/preprocessor_config.json
# ['./weights/convnext-tiny-224_feature_extractor/preprocessor_config.json']

# %%
preds_test = trainer.predict(test_dataset)
np.save('./conv_preds.npy', preds_test)
test['class'] = np.argmax(preds_test.predictions, axis=1)
test.to_csv('conv_90epoch.csv', index=False)
# Out:
# ***** Running Prediction *****
#   Num examples = 2138
#   Batch size = 16
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
